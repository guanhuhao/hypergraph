# %%
import random as random
import time as time
import heapq as heapq
import matplotlib.pyplot as plt # 画曲线图
import numpy as np #拟合直线

class HyperNode:
    def __init__(self,id,degree,edges):
        self.id = id
        self.degree = degree
        self.edges = edges

    def __lt__(self,other):
        return self.id<other.id
    
    def print(self):
        print("id:" + str(self.id))
        print("degree:" + str(self.degree))
        print("edges: "+ str(self.edges))

class HyperEdge:
    def __init__(self,id,degree,nodes):
        self.id = id
        self.degree = degree 
        self.nodes = nodes
        
    def print(self):
        print("id:" + str(self.id))
        print("degree:" + str(self.degree))
        print("edges: "+ str(self.nodes))

# # return: mp_node,mp_edge
# def load_data(path):
#     # input:
#     # path: data set path
    
#     # return: 
#     # mp_node: dict of partition node n_id:HyperNode
#     # mp_edge: dict of partition edge e_id:HyperEdge
    
#     mp_node = {}
#     mp_edge = {}
#     with open(path,'r') as f:
#         for line in f:
#             if(line[0]=='#' or line=='\n') : continue
#             data = [int(i) for i in line[0:-1].split(" ")]
#             n_id = data[0]
#             n_degree = data[1]
#             n_edges = set(data[2:])
#             if mp_node.get(n_id) == None : 
#                 mp_node[n_id] = HyperNode(n_id,n_degree,n_edges)
#                 tmp[n_id] = HyperNode(n_id,n_degree,n_edges)
#             for edge in n_edges:
#                 if mp_edge.get(edge) == None:
#                     mp_edge[edge] = HyperEdge(edge,0,set())
#                 mp_edge[edge].degree += 1
#                 mp_edge[edge].nodes.add(n_id)
#     return mp_node,mp_edge

# return: mp_node,mp_edge
def load_data(path):
    # input:
    # path: data set path
    
    # return: 
    # mp_node: dict of partition node n_id:HyperNode
    # mp_edge: dict of partition edge e_id:HyperEdge
    
    mp_node = {}
    mp_edge = {}
    with open(path,'r') as f:
        for line in f:
#             print(line[0:-1].split(" "))
            n_id,e_id = line[0:-1].split(" ")
            if mp_node.get(n_id) == None : 
                mp_node[n_id] = HyperNode(n_id,0,set())
            if mp_edge.get(e_id) == None :
                mp_edge[e_id] = HyperEdge(e_id,0,set())
                
            mp_node[n_id].degree += 1
            mp_edge[e_id].degree += 1
            mp_node[n_id].edges.add(e_id)
            mp_edge[e_id].nodes.add(n_id)
    return mp_node,mp_edge

# return: None
def recoder(part_node,mp_node,mp_edge,path):
    # input:
    # part_node: result of partition nodemp_eval[node.id] - node.degree
    # mp_node: dictionary of hyper node 
    # mp_edge: dictionary of hyper edge
    # path: path to save record result
    
    dic = {}
    tot = 0
    for par in part_node:
        for node in par:
            dic[node.id] = len(dic)

    print(path+"/record.txt")
    with open(path+"/record.txt",'w') as f:
        for par in part_node:
            for node in par:
                for edge in node.edges:
                    f.write(str(dic[node.id])+" "+str(edge)+"\n")
# return: part_node,part_edge
class Heap:
    def __init__(self):
        self.heap = []
        self.check = set()
        
    def add(self,rank,item):
        if item in self.check : return
        heapq.heappush(self.heap,(rank,item))
        self.check.add(item)
        
    def pop(self):
        rank,item = heapq.heappop(self.heap)
        self.check.remove(item)
        return rank,item
    
    def clear(self):
        self.check.clear()
        self.heap = []
        
    def check(self,item):
        return item in self.check
    
    def size(self):
#         print(self.heap)
        return len(self.heap)
    
    def top(self):
        return self.heap[0]
    
    def remake(self,ls):
#         print("before:",self.heap)
        heapq.heapify(ls)
        self.heap = ls
#         print("after:",self.heap)
        
def solve(p,mp_node,mp_edge,prop = 1.0,k=1,shield_heavy_edge = 1e9 ,buffer_fac = 5,debug = False):
    # input : 
    # p: partition number 
    # mp_node: dict of partition nodes  
    # mp_edge: dict of partition edges
    # prob: accelerate factory to add node
    # k: select topk node at once
    # shield_heavy_node: filter huge edge 
    # debug: print debug infomation
    
    # return :
    # part_node: list of partition node set 
    # part_edge: list of partition edge set
    
    random.seed(19990320)
    node_number = len(mp_node)
    cur_p = 0
    maxi_cap = node_number/p + 1
    part_node = [set() for i in range(p)]
    part_edge = [set() for i in range(p)]
    mp_eval = {i:0 for i in mp_node.keys()}
    
    ave_hyperedge_degree = 0
    edge_degree_list = set()
    for edge in mp_edge.values():   
        ave_hyperedge_degree += edge.degree/len(mp_edge)
        edge_degree_list.add(edge.degree)
#     print(edge_degree_list)
    edge_degree_list = list(edge_degree_list)
    edge_degree_list.sort()
#     print(edge_degree_list)
#     print(len(mp_edge)/2)
#     print("2*ave:",ave_hyperedge_degree," mid:",edge_degree_list[int(len(edge_degree_list)/2)])
    ave_hyperedge_degree = edge_degree_list[int(len(edge_degree_list)/2)]

    cnt = 0
    select_node = Heap()
    heap_size = buffer_fac*k
    while len(mp_node)!=0:
        cnt += 1
        if cnt % 100 == 0 and debug : print (cnt)
            
        add_node = []
        
        if select_node.size() <= k:
            select_node.clear()
            for node in mp_node.values():   
                if  select_node.size() < heap_size:
                    select_node.add(mp_eval[node.id],node)
                else :
                    if mp_eval[node.id] > select_node.top()[0] :
                        rank,remove_node = select_node.pop()
                        select_node.add(mp_eval[node.id],node)
        
        for i in range(min(k,select_node.size())):
            rank,node = select_node.pop()
            add_node.append(node)

        for par_node in add_node:
            if len(part_node[cur_p]) >= maxi_cap :
                break
            part_node[cur_p].add(par_node)
            for edge in par_node.edges:
                if edge not in part_edge[cur_p]:
                    part_edge[cur_p].add(edge)
                    if mp_edge[edge].degree > shield_heavy_edge: continue
                    for node in mp_edge[edge].nodes:
                        if mp_node.get(node) == None : continue
                        mp_eval[node] += 1
#                         print(len(select_node))
            del mp_node[par_node.id] 
        remake_ls = [(mp_eval[node.id],node) for rank,node in select_node.heap]
#         print(remake_ls)
        select_node.remake(remake_ls)

        if len(part_node[cur_p]) >= maxi_cap : # next partition pre-process
            for key in mp_eval.keys():
                mp_eval[key] = 0
            cur_p += 1   
            
    return part_node,part_edge
        
        
def solve2(p,mp_node,mp_edge,prop = 1.0,k=1,shield_heavy_edge = 1e9 ,buffer_fac = 5,debug = False):
    # input : 
    # p: partition number 
    # mp_node: dict of partition nodes  
    # mp_edge: dict of partition edges
    # prob: accelerate factory to add node
    # k: select topk node at once
    # shield_heavy_node: filter huge edge 
    # debug: print debug infomation
    
    # return :
    # part_node: list of partition node set 
    # part_edge: list of partition edge set
    
    random.seed(19990320)
    node_number = len(mp_node)
    cur_p = 0
    maxi_cap = node_number/p + 1
    part_node = [set() for i in range(p)]
    part_edge = [set() for i in range(p)]
    mp_eval = {i:0 for i in mp_node.keys()}

    cnt = 0
    select_node = Heap()
    heap_size = buffer_fac*k
    
    while len(mp_node)!=0:
        cnt += 1
        if cnt % 100 == 0 and debug : print (cnt)
            
        add_node = []
        
        if select_node.size() <= k:
            select_node.clear()
            for node in mp_node.values(): 
                if mp_eval[node.id] == 0 : 
                    if select_node.size() < heap_size : 
                        select_node.add(-1e9,node)
                    else : continue
                if  select_node.size() < heap_size:
                    select_node.add(mp_eval[node.id] - node.degree,node)
                else :
                    if mp_eval[node.id] - node.degree > select_node.top()[0] :
                        rank,remove_node = select_node.pop()
                        select_node.add(mp_eval[node.id] - node.degree,node)
        
        for i in range(min(k,select_node.size())):
            rank,node = select_node.pop()
            add_node.append(node)

        for par_node in add_node:
            if len(part_node[cur_p]) >= maxi_cap :
                break
            part_node[cur_p].add(par_node)
            for edge in par_node.edges:
                if edge not in part_edge[cur_p]:
                    part_edge[cur_p].add(edge)
                    if mp_edge[edge].degree > shield_heavy_edge: continue
                    for node in mp_edge[edge].nodes:
                        if mp_node.get(node) == None : continue
                        mp_eval[node] += 1
#                         print(len(select_node))
            del mp_node[par_node.id] 
        remake_ls = [(mp_eval[node.id]-node.degree,node)for rank,node in select_node.heap]
        select_node.remake(remake_ls)

        if len(part_node[cur_p]) >= maxi_cap : # next partition pre-process
            for key in mp_eval.keys():
                mp_eval[key] = 0
            cur_p += 1   
            
    return part_node,part_edge



def degree_distribute(mp_node,show = True,logx=True,logy=True,coeff = True,cumulation = True): # draw degree distribute graph 
    degree = mp_node
    dic = {j.degree:0 for i,j in degree.items()}
    
    for i,j in degree.items(): dic[j.degree] += 1
    
    ls = sorted(dic.items(), key = lambda x:(x[0],x[1]))
        
    x = [i[0] for i in ls]
    y = [i[1] for i in ls]

    if x[0] == 0:
        x = x[1:-1]
        y = y[1:-1]
    
    if cumulation == True : 
        cnt = sum(y)
        for i in range(len(x)):
            cnt -= y[i]
            y[i] += cnt

    if show == True :
        plt.plot(x,y, 'o',color='b')
        if logy : plt.yscale('log')
        if logx : plt.xscale('log')
        

    if coeff == True : 

        xx = [np.log2(i) for i in x]
        yy = [np.log2(i) for i in y]
        
        k,b = np.polyfit(xx, yy, 1)
#         lg = yy[0]/xx[-1]
#         lg = 1/lg
        print("alpha: "+str(k))
        
        xx = x
        yy = [(i**k)*(2**b) for i in xx]
        plt.plot(xx,yy,color='r')
    plt.show()

    return [(x[i],y[i]) for i in range(len(x))]

# %%
# path = "./data/github/github.txt"
path = "./data/wiki/wiki.txt"
p = 1
mp_node,mp_edge = load_data(path)
ls = degree_distribute(mp_node)
for turn in range(8):
    p*=2
    prop = 1.1
    k = 1
    buffer_fac = 3
    shield_heavy_edge = 1e9
    mp_node,mp_edge = load_data(path)
#     degree_distribute(mp_node)
    time_beg = time.time()
    part_node,part_edge = solve(p,mp_node,mp_edge,prop,k,buffer_fac = buffer_fac,shield_heavy_edge = shield_heavy_edge)  
    time_end = time.time()
    mp_node,mp_edge = load_data(path)
    # recoder(part_node,mp_node,mp_edge,"./data/wiki")
    k_1 = sum([len(i) for i in part_edge]) - len(mp_edge)
#     print(turn," ",k_1)
    print("parameter:\n","p:",p," prop:","%.2f"%prop," k:",k," buffer_fac:",buffer_fac,
          " sheld_size:",shield_heavy_edge)
    print("result1:\n","runtime:",int((time_end-time_beg)*1000),"ms k-1:",k_1)
    mp_node,mp_edge = load_data(path)
#     degree_distribute(mp_node)
    time_beg = time.time()
    part_node,part_edge = solve2(p,mp_node,mp_edge,prop,k,buffer_fac = buffer_fac,shield_heavy_edge = shield_heavy_edge)  
    time_end = time.time()
    mp_node,mp_edge = load_data(path)
    # recoder(part_node,mp_node,mp_edge,"./data/wiki")
    k_1 = sum([len(i) for i in part_edge]) - len(mp_edge)
    print("result2:\n","runtime:",int((time_end-time_beg)*1000),"ms k-1:",k_1)
    print("---------------------------------------")
#  runtime: 11999 ms k-1: 27102
# Out:
# alpha: -1.733355505918805
# [(0, <__main__.HyperNode object at 0x7f6c41642cf8>), (0, <__main__.HyperNode object at 0x7f6c3fd4fc88>)]
# [(1, <__main__.HyperNode object at 0x7f6c3fd4fc88>)]
# [(33, <__main__.HyperNode object at 0x7f6c3fee74e0>), (31, <__main__.HyperNode object at 0x7f6c4cf7f780>)]
# [(70, <__main__.HyperNode object at 0x7f6c3fee74e0>)]
# [(93, <__main__.HyperNode object at 0x7f6c4d3fb898>), (90, <__main__.HyperNode object at 0x7f6c4c365908>)]
# [(103, <__main__.HyperNode object at 0x7f6c4d3fb898>)]
# [(229, <__main__.HyperNode object at 0x7f6c415ad710>), (236, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(240, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(207, <__main__.HyperNode object at 0x7f6c4dad7d68>), (240, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(242, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(167, <__main__.HyperNode object at 0x7f6c4cf7ec88>), (243, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(170, <__main__.HyperNode object at 0x7f6c4ca8c390>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(159, <__main__.HyperNode object at 0x7f6c40b14cc0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(152, <__main__.HyperNode object at 0x7f6c4bfe33c8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(150, <__main__.HyperNode object at 0x7f6c40b3d588>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(142, <__main__.HyperNode object at 0x7f6c4e3cf400>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(140, <__main__.HyperNode object at 0x7f6c4ce53b00>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(136, <__main__.HyperNode object at 0x7f6c4d38a128>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(134, <__main__.HyperNode object at 0x7f6c4e391c50>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(131, <__main__.HyperNode object at 0x7f6c4051fc88>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(130, <__main__.HyperNode object at 0x7f6c4d7167b8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(130, <__main__.HyperNode object at 0x7f6c4d3fb898>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(130, <__main__.HyperNode object at 0x7f6c3f9175f8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(126, <__main__.HyperNode object at 0x7f6c4b7717f0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(122, <__main__.HyperNode object at 0x7f6c3f9e6c88>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(118, <__main__.HyperNode object at 0x7f6c4d3405f8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(119, <__main__.HyperNode object at 0x7f6c3fece400>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(112, <__main__.HyperNode object at 0x7f6c4cf15a90>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(111, <__main__.HyperNode object at 0x7f6c4e38ee10>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(112, <__main__.HyperNode object at 0x7f6c4de93ba8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(109, <__main__.HyperNode object at 0x7f6c4d76fa90>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(106, <__main__.HyperNode object at 0x7f6c4df18630>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(104, <__main__.HyperNode object at 0x7f6c4db1fe80>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(106, <__main__.HyperNode object at 0x7f6c4cf66940>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(101, <__main__.HyperNode object at 0x7f6c4df1d7b8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(104, <__main__.HyperNode object at 0x7f6c4de945c0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(101, <__main__.HyperNode object at 0x7f6c4c3322e8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(100, <__main__.HyperNode object at 0x7f6c4d3b75c0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(100, <__main__.HyperNode object at 0x7f6c4db28240>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(98, <__main__.HyperNode object at 0x7f6c4d6ff470>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(98, <__main__.HyperNode object at 0x7f6c40a9d470>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(97, <__main__.HyperNode object at 0x7f6c4c705748>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(96, <__main__.HyperNode object at 0x7f6c4e687ac8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(95, <__main__.HyperNode object at 0x7f6c40bf30b8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(93, <__main__.HyperNode object at 0x7f6c4d6dd208>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(94, <__main__.HyperNode object at 0x7f6c40d910b8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(90, <__main__.HyperNode object at 0x7f6c4c372320>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(91, <__main__.HyperNode object at 0x7f6c40d9fc18>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(91, <__main__.HyperNode object at 0x7f6c4dbb20b8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(90, <__main__.HyperNode object at 0x7f6c4e6ba160>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(89, <__main__.HyperNode object at 0x7f6c4db69978>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(88, <__main__.HyperNode object at 0x7f6c4bf727b8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(88, <__main__.HyperNode object at 0x7f6c40bf1dd8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(86, <__main__.HyperNode object at 0x7f6c4cff84e0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(85, <__main__.HyperNode object at 0x7f6c4da91ac8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(84, <__main__.HyperNode object at 0x7f6c4da4f048>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(83, <__main__.HyperNode object at 0x7f6c4d3d17f0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(83, <__main__.HyperNode object at 0x7f6c4b3c6a20>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(84, <__main__.HyperNode object at 0x7f6c40f482b0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(82, <__main__.HyperNode object at 0x7f6c4b2f2ef0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(83, <__main__.HyperNode object at 0x7f6c4d72d588>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(82, <__main__.HyperNode object at 0x7f6c4c31fd30>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(83, <__main__.HyperNode object at 0x7f6c4b2e9630>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(83, <__main__.HyperNode object at 0x7f6c3fea2128>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(88, <__main__.HyperNode object at 0x7f6c4163ecc0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(83, <__main__.HyperNode object at 0x7f6cec5a6080>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(82, <__main__.HyperNode object at 0x7f6c40d5fda0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(81, <__main__.HyperNode object at 0x7f6c4db3cda0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(80, <__main__.HyperNode object at 0x7f6c4b2ff550>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(80, <__main__.HyperNode object at 0x7f6c4ce746a0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(79, <__main__.HyperNode object at 0x7f6c403a3908>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(79, <__main__.HyperNode object at 0x7f6c4d25f9e8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(78, <__main__.HyperNode object at 0x7f6c4dbac978>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(78, <__main__.HyperNode object at 0x7f6c4cedc978>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(78, <__main__.HyperNode object at 0x7f6c4b3776d8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(77, <__main__.HyperNode object at 0x7f6c4ca84240>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(77, <__main__.HyperNode object at 0x7f6c4c783668>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(76, <__main__.HyperNode object at 0x7f6c4bbdad68>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(77, <__main__.HyperNode object at 0x7f6c4e6904a8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(76, <__main__.HyperNode object at 0x7f6c4d39be80>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(75, <__main__.HyperNode object at 0x7f6c4b7a40f0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(75, <__main__.HyperNode object at 0x7f6c40b4f240>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(75, <__main__.HyperNode object at 0x7f6c40ddbc18>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(74, <__main__.HyperNode object at 0x7f6c4c68b198>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(74, <__main__.HyperNode object at 0x7f6c4dbb4320>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(74, <__main__.HyperNode object at 0x7f6c4dbc5b00>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(74, <__main__.HyperNode object at 0x7f6c40407f98>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(73, <__main__.HyperNode object at 0x7f6c4052a7b8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(72, <__main__.HyperNode object at 0x7f6c4cb317b8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(72, <__main__.HyperNode object at 0x7f6c4cec08d0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(72, <__main__.HyperNode object at 0x7f6c4d3a0908>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(71, <__main__.HyperNode object at 0x7f6c4e317518>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(71, <__main__.HyperNode object at 0x7f6c4b309940>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(71, <__main__.HyperNode object at 0x7f6c4b34d048>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(70, <__main__.HyperNode object at 0x7f6c4bff4e48>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(70, <__main__.HyperNode object at 0x7f6c4ca7c198>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(69, <__main__.HyperNode object at 0x7f6c40d57908>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(69, <__main__.HyperNode object at 0x7f6c40a9c3c8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(69, <__main__.HyperNode object at 0x7f6c4d37bbe0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(68, <__main__.HyperNode object at 0x7f6c4c39c5c0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(70, <__main__.HyperNode object at 0x7f6c4bb83438>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(119, <__main__.HyperNode object at 0x7f6c4db93390>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(69, <__main__.HyperNode object at 0x7f6c4c6e9128>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(68, <__main__.HyperNode object at 0x7f6c4d28f240>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(68, <__main__.HyperNode object at 0x7f6c40bf7748>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(67, <__main__.HyperNode object at 0x7f6c4b76b668>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(67, <__main__.HyperNode object at 0x7f6c4c7ef2e8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(67, <__main__.HyperNode object at 0x7f6c4c2c7b70>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(66, <__main__.HyperNode object at 0x7f6c4c730710>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(66, <__main__.HyperNode object at 0x7f6c4163fc88>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(66, <__main__.HyperNode object at 0x7f6c4db6d080>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(66, <__main__.HyperNode object at 0x7f6c4e711ac8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(66, <__main__.HyperNode object at 0x7f6c4baf1e80>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(66, <__main__.HyperNode object at 0x7f6c40db7d68>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(65, <__main__.HyperNode object at 0x7f6c3f9ff518>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(65, <__main__.HyperNode object at 0x7f6c4d348a20>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(65, <__main__.HyperNode object at 0x7f6c4e3d39b0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(64, <__main__.HyperNode object at 0x7f6c4c2dbf98>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(64, <__main__.HyperNode object at 0x7f6c4ced6ef0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(64, <__main__.HyperNode object at 0x7f6c40ae4080>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(63, <__main__.HyperNode object at 0x7f6c41638780>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(63, <__main__.HyperNode object at 0x7f6c40a60da0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(63, <__main__.HyperNode object at 0x7f6c3f937a58>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(63, <__main__.HyperNode object at 0x7f6c40bf8860>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(62, <__main__.HyperNode object at 0x7f6c4bb7cd30>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(62, <__main__.HyperNode object at 0x7f6c4db9fba8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(62, <__main__.HyperNode object at 0x7f6c4cec92e8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(62, <__main__.HyperNode object at 0x7f6c40aedef0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(61, <__main__.HyperNode object at 0x7f6c4c2ee4a8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(61, <__main__.HyperNode object at 0x7f6c4e3b8c88>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(61, <__main__.HyperNode object at 0x7f6c4d79f080>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(61, <__main__.HyperNode object at 0x7f6c4046c828>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(60, <__main__.HyperNode object at 0x7f6c4bfb1a20>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(60, <__main__.HyperNode object at 0x7f6c4e666c18>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(60, <__main__.HyperNode object at 0x7f6c4d29dc50>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(60, <__main__.HyperNode object at 0x7f6c4e2ec208>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(60, <__main__.HyperNode object at 0x7f6c4bb007f0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(60, <__main__.HyperNode object at 0x7f6c4baa2940>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(60, <__main__.HyperNode object at 0x7f6c4e389908>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(60, <__main__.HyperNode object at 0x7f6c4110ae10>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(59, <__main__.HyperNode object at 0x7f6c4c333080>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(59, <__main__.HyperNode object at 0x7f6c4c6bf160>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(59, <__main__.HyperNode object at 0x7f6c4bbe6f60>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(59, <__main__.HyperNode object at 0x7f6c4e3cac50>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(59, <__main__.HyperNode object at 0x7f6c4b2dc668>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(59, <__main__.HyperNode object at 0x7f6c4d75e438>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(59, <__main__.HyperNode object at 0x7f6c40d70668>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(59, <__main__.HyperNode object at 0x7f6c4cfcedd8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(58, <__main__.HyperNode object at 0x7f6c4d7f38d0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(58, <__main__.HyperNode object at 0x7f6c4cb42240>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(58, <__main__.HyperNode object at 0x7f6c4c399588>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(58, <__main__.HyperNode object at 0x7f6c4ca7f4a8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(58, <__main__.HyperNode object at 0x7f6c4babbef0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(58, <__main__.HyperNode object at 0x7f6c4dfe5c50>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(58, <__main__.HyperNode object at 0x7f6c4c69ee48>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(58, <__main__.HyperNode object at 0x7f6c4d252128>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(58, <__main__.HyperNode object at 0x7f6c40410470>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(58, <__main__.HyperNode object at 0x7f6c40396940>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(57, <__main__.HyperNode object at 0x7f6c4e73ada0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(57, <__main__.HyperNode object at 0x7f6c4bb10160>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(57, <__main__.HyperNode object at 0x7f6c40437828>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(59, <__main__.HyperNode object at 0x7f6c4e6be400>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(57, <__main__.HyperNode object at 0x7f6c4db7c7f0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(57, <__main__.HyperNode object at 0x7f6cec595be0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(57, <__main__.HyperNode object at 0x7f6c40be9cf8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(57, <__main__.HyperNode object at 0x7f6c4cf4bcc0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(56, <__main__.HyperNode object at 0x7f6c4c74c128>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(56, <__main__.HyperNode object at 0x7f6c4bbd6e48>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(56, <__main__.HyperNode object at 0x7f6c4da9ccf8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(56, <__main__.HyperNode object at 0x7f6c4dae55c0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(56, <__main__.HyperNode object at 0x7f6c4b3bed68>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(57, <__main__.HyperNode object at 0x7f6c4db1e160>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(56, <__main__.HyperNode object at 0x7f6c4e6f1b38>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(57, <__main__.HyperNode object at 0x7f6c404cf358>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(56, <__main__.HyperNode object at 0x7f6c40a9f7b8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(56, <__main__.HyperNode object at 0x7f6c4d3b31d0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(55, <__main__.HyperNode object at 0x7f6c4daa32b0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(55, <__main__.HyperNode object at 0x7f6c4c3c3e80>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(55, <__main__.HyperNode object at 0x7f6c4b39fcc0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(55, <__main__.HyperNode object at 0x7f6c4c310588>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(55, <__main__.HyperNode object at 0x7f6c4bb37eb8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(55, <__main__.HyperNode object at 0x7f6c40dbecc0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(55, <__main__.HyperNode object at 0x7f6c4cfccc88>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(55, <__main__.HyperNode object at 0x7f6c40ab4a90>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(54, <__main__.HyperNode object at 0x7f6c4e38b320>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(54, <__main__.HyperNode object at 0x7f6c4b3535c0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(54, <__main__.HyperNode object at 0x7f6c4cfa49b0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(54, <__main__.HyperNode object at 0x7f6c4e2f17f0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(54, <__main__.HyperNode object at 0x7f6c4c69b5c0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(54, <__main__.HyperNode object at 0x7f6c4c6e8240>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(54, <__main__.HyperNode object at 0x7f6c40bdfe48>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(54, <__main__.HyperNode object at 0x7f6c3fecbba8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(54, <__main__.HyperNode object at 0x7f6c404dafd0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(54, <__main__.HyperNode object at 0x7f6c4cfef208>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(53, <__main__.HyperNode object at 0x7f6c4dec8da0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(53, <__main__.HyperNode object at 0x7f6c4c3a7b70>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(54, <__main__.HyperNode object at 0x7f6c4bbbebe0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(54, <__main__.HyperNode object at 0x7f6c4bae3e48>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(53, <__main__.HyperNode object at 0x7f6c4df89400>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(53, <__main__.HyperNode object at 0x7f6c4b24b2b0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(53, <__main__.HyperNode object at 0x7f6c4ce66898>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(53, <__main__.HyperNode object at 0x7f6c41105668>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(53, <__main__.HyperNode object at 0x7f6c40ba7f60>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(52, <__main__.HyperNode object at 0x7f6c4cae5b00>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(52, <__main__.HyperNode object at 0x7f6c4df532e8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(52, <__main__.HyperNode object at 0x7f6c4cb7c128>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(52, <__main__.HyperNode object at 0x7f6c4dfedba8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(53, <__main__.HyperNode object at 0x7f6c40bfa710>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(52, <__main__.HyperNode object at 0x7f6c4dfdbb70>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(52, <__main__.HyperNode object at 0x7f6c4de59a90>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(52, <__main__.HyperNode object at 0x7f6c4d772da0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(52, <__main__.HyperNode object at 0x7f6c4cb54b38>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(52, <__main__.HyperNode object at 0x7f6c40b2aeb8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(51, <__main__.HyperNode object at 0x7f6c4dae9d30>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(51, <__main__.HyperNode object at 0x7f6c4dbd7390>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(51, <__main__.HyperNode object at 0x7f6c4bb2db00>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(51, <__main__.HyperNode object at 0x7f6c4d722c50>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(51, <__main__.HyperNode object at 0x7f6c4bf5b4a8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(51, <__main__.HyperNode object at 0x7f6c4dac1be0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(51, <__main__.HyperNode object at 0x7f6c4cff56a0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(51, <__main__.HyperNode object at 0x7f6c4c3ba550>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(50, <__main__.HyperNode object at 0x7f6c4db13d68>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(50, <__main__.HyperNode object at 0x7f6c4e676828>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(50, <__main__.HyperNode object at 0x7f6c4d3c79b0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(50, <__main__.HyperNode object at 0x7f6c4cf9d940>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(50, <__main__.HyperNode object at 0x7f6c4dbdddd8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(50, <__main__.HyperNode object at 0x7f6c4dbcb7b8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(51, <__main__.HyperNode object at 0x7f6c3f9223c8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(50, <__main__.HyperNode object at 0x7f6c4bff56a0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(50, <__main__.HyperNode object at 0x7f6c4c36a470>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(50, <__main__.HyperNode object at 0x7f6c3fed76d8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(50, <__main__.HyperNode object at 0x7f6c40417438>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(50, <__main__.HyperNode object at 0x7f6c40deab38>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(50, <__main__.HyperNode object at 0x7f6c40ae6f98>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(49, <__main__.HyperNode object at 0x7f6c4d695b70>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(49, <__main__.HyperNode object at 0x7f6c4d2ac048>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(49, <__main__.HyperNode object at 0x7f6c4c6ed240>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(49, <__main__.HyperNode object at 0x7f6c4bf45f60>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(50, <__main__.HyperNode object at 0x7f6c4e6e17b8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(49, <__main__.HyperNode object at 0x7f6c4daf2860>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(49, <__main__.HyperNode object at 0x7f6c4debbef0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(49, <__main__.HyperNode object at 0x7f6c4c323518>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(49, <__main__.HyperNode object at 0x7f6c4ceffda0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(49, <__main__.HyperNode object at 0x7f6c4c3a56a0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(49, <__main__.HyperNode object at 0x7f6c4d6dce80>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(49, <__main__.HyperNode object at 0x7f6c40403358>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(49, <__main__.HyperNode object at 0x7f6c40a9e908>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(49, <__main__.HyperNode object at 0x7f6c4d3a49b0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(48, <__main__.HyperNode object at 0x7f6c4dea9240>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(48, <__main__.HyperNode object at 0x7f6c4cf17ba8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(48, <__main__.HyperNode object at 0x7f6c4d7ad518>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(48, <__main__.HyperNode object at 0x7f6c4daafb38>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(48, <__main__.HyperNode object at 0x7f6c4d70a668>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(48, <__main__.HyperNode object at 0x7f6c4deb1940>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(48, <__main__.HyperNode object at 0x7f6c4ca40fd0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(48, <__main__.HyperNode object at 0x7f6c4df82c18>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(48, <__main__.HyperNode object at 0x7f6c4d7ae978>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(48, <__main__.HyperNode object at 0x7f6c4df20898>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(48, <__main__.HyperNode object at 0x7f6c4de67a20>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(48, <__main__.HyperNode object at 0x7f6c4c740978>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(48, <__main__.HyperNode object at 0x7f6c4cb91630>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(48, <__main__.HyperNode object at 0x7f6c40bdd5c0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(48, <__main__.HyperNode object at 0x7f6c40d9dcf8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(48, <__main__.HyperNode object at 0x7f6c40d47ef0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(48, <__main__.HyperNode object at 0x7f6c40ac97b8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(47, <__main__.HyperNode object at 0x7f6c4db8fcc0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(47, <__main__.HyperNode object at 0x7f6c4dea8cf8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(47, <__main__.HyperNode object at 0x7f6c4e3d82b0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(48, <__main__.HyperNode object at 0x7f6c4bf746d8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(47, <__main__.HyperNode object at 0x7f6c4e30d978>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(47, <__main__.HyperNode object at 0x7f6c4cb22320>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(47, <__main__.HyperNode object at 0x7f6c4e3c9828>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(47, <__main__.HyperNode object at 0x7f6c4e367fd0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(47, <__main__.HyperNode object at 0x7f6c4daac6d8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(47, <__main__.HyperNode object at 0x7f6c4baaa518>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(47, <__main__.HyperNode object at 0x7f6c4d280080>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(47, <__main__.HyperNode object at 0x7f6c4c3cec50>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(47, <__main__.HyperNode object at 0x7f6c4c3ee278>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(47, <__main__.HyperNode object at 0x7f6c403a4400>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(47, <__main__.HyperNode object at 0x7f6c41859208>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(47, <__main__.HyperNode object at 0x7f6c40dc7e48>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(47, <__main__.HyperNode object at 0x7f6c40b1d748>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(47, <__main__.HyperNode object at 0x7f6c4cfd1cc0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(46, <__main__.HyperNode object at 0x7f6c4b662470>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(46, <__main__.HyperNode object at 0x7f6c4d7307f0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(47, <__main__.HyperNode object at 0x7f6c4bbec908>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(46, <__main__.HyperNode object at 0x7f6c4bb457f0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(46, <__main__.HyperNode object at 0x7f6c4db44748>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(46, <__main__.HyperNode object at 0x7f6c4c3225c0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(46, <__main__.HyperNode object at 0x7f6c4def0f60>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(46, <__main__.HyperNode object at 0x7f6c4e2e4278>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(46, <__main__.HyperNode object at 0x7f6c4df44390>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(46, <__main__.HyperNode object at 0x7f6c4db7eb70>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(46, <__main__.HyperNode object at 0x7f6c4bf33ef0>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(46, <__main__.HyperNode object at 0x7f6c40484f28>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(46, <__main__.HyperNode object at 0x7f6c40d42b38>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(46, <__main__.HyperNode object at 0x7f6c40b03438>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(45, <__main__.HyperNode object at 0x7f6c402770b8>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(45, <__main__.HyperNode object at 0x7f6c3fd5b208>), (244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# [(244, <__main__.HyperNode object at 0x7f6c4bb8af28>)]
# ...
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c4cac5240>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c4d6ef550>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c4e374c88>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c4e72a198>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c4cb422b0>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c4cf76cf8>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c40dd2278>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c4d38ff28>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c4c68ccc0>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c40abd9b0>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c4c786048>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c4cecbb70>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c404d4b70>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c40aeb898>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(15, <__main__.HyperNode object at 0x7f6c41855cf8>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c40a98668>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c4c7a9748>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c4b7a48d0>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c415bf198>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c4047dfd0>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c3f937320>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c4d27fb38>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c4caede10>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c4c7f6e10>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c4daab080>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c40bfb6a0>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c40d75f98>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c4cfc8438>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c4de40cc0>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c4bb192b0>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c3f93de48>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c40d75780>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c4cb6e3c8>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c41843438>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c4dfb56d8>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c4046d080>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c4ce49208>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(16, <__main__.HyperNode object at 0x7f6c4e357f60>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(17, <__main__.HyperNode object at 0x7f6c41598198>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(17, <__main__.HyperNode object at 0x7f6c4de56d68>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(16, <__main__.HyperNode object at 0x7f6c4cf552b0>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(17, <__main__.HyperNode object at 0x7f6c4cf44320>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(15, <__main__.HyperNode object at 0x7f6c4b3496d8>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c4cf4c358>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c40d77748>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c4baa07f0>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c4bb79d68>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c4c2c3be0>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c4ded0f98>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c4dffa898>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c4d39cf28>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c4da9b7b8>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c4bf062b0>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c4cf4aa90>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c4d2a40f0>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c4cbb1780>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c40aae668>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c4b745470>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c40b2d128>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c4e2c2748>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c40ba0390>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c4bac2128>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(15, <__main__.HyperNode object at 0x7f6c4da78588>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(15, <__main__.HyperNode object at 0x7f6c3fed3e10>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c411174e0>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c40df1630>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(15, <__main__.HyperNode object at 0x7f6c4045f550>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c3fecb048>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c4cfa2390>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c4bf21898>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c40aa9be0>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c40ae9f28>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c4d274278>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c4db0ada0>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c40addf28>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c4c35e748>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c4d38bc88>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c4c7b18d0>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c4db0e2e8>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c4047ae80>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c404c91d0>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c40adf940>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c4c7392e8>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c40a68860>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c4e6d0a20>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c415b10f0>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c4c3d5b00>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c4cbafc50>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c4df049e8>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c4cbb9898>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(13, <__main__.HyperNode object at 0x7f6c4c3a9be0>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(14, <__main__.HyperNode object at 0x7f6c4e737a90>), (18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# [(18, <__main__.HyperNode object at 0x7f6c4e6cdf98>)]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-65089b42e7f9> in <module>
#      13 #     degree_distribute(mp_node)
#      14     time_beg = time.time()
# ---> 15     part_node,part_edge = solve(p,mp_node,mp_edge,prop,k,buffer_fac = buffer_fac,shield_heavy_edge = shield_heavy_edge)
#      16     time_end = time.time()
#      17     mp_node,mp_edge = load_data(path)
#
# <ipython-input-15-eed90bd5aae3> in solve(p, mp_node, mp_edge, prop, k, shield_heavy_edge, buffer_fac, debug)
#     187             select_node.clear()
#     188             for node in mp_node.values():
# --> 189                 if  select_node.size() < heap_size:
#     190                     select_node.add(mp_eval[node.id],node)
#     191                 else :
#
# <ipython-input-15-eed90bd5aae3> in size(self)
#     129     def size(self):
#     130 #         print(self.heap)
# --> 131         return len(self.heap)
#     132
#     133     def top(self):
#
# KeyboardInterrupt:

# %%
def test_shield():
    x = []
    y = []
#     path = "./data/wiki/wiki.txt"
    path = "./data/github/github.txt"
    p = 16
    mp_node,mp_edge = load_data(path)
    ls = degree_distribute(mp_node)
    for turn in range(61,81):
    #     p*=2
        mp_node,mp_edge = load_data(path)
    #     degree_distribute(mp_node)
        time_beg = time.time()
        prop = 1.1
        k = 10
        buffer_fac = 1
        shield_heavy_edge = turn
        part_node,part_edge = solve(p,mp_node,mp_edge,prop,k,buffer_fac = buffer_fac,shield_heavy_edge = shield_heavy_edge)  
        time_end = time.time()
        mp_node,mp_edge = load_data(path)
        # recoder(part_node,mp_node,mp_edge,"./data/wiki")
        k_1 = sum([len(i) for i in part_edge]) - len(mp_edge)
#         print(turn," ",k_1)
        x.append(turn)
        y.append(k_1)
    plt.plot(x,y,color='r')
    plt.show()
    return x,y
    
x,y = test_shield()
# Out:
# alpha: -1.6363240049196743
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-380cda46f3d1> in <module>
#      28     return x,y
#      29
# ---> 30 x,y = test_shield()
#
# <ipython-input-23-380cda46f3d1> in test_shield()
#      16         buffer_fac = 1
#      17         shield_heavy_edge = turn
# ---> 18         part_node,part_edge = solve(p,mp_node,mp_edge,prop,k,buffer_fac = buffer_fac,shield_heavy_edge = shield_heavy_edge)
#      19         time_end = time.time()
#      20         mp_node,mp_edge = load_data(path)
#
# <ipython-input-18-cdca903dea21> in solve(p, mp_node, mp_edge, prop, k, shield_heavy_edge, buffer_fac, debug)
#     156                     heapq.heappush(select_node,(mp_eval[node.id],node))
#     157                 else :
# --> 158                     if mp_eval[node.id] > select_node[0][0] :
#     159                         rank,remove_node = heapq.heappop(select_node)
#     160                         heapq.heappush(select_node,(mp_eval[node.id],node))
#
# KeyboardInterrupt:

# %%
path = "./data/github/github.txt"
mp_node,mp_edge = load_data(path)
ls = degree_distribute(mp_node)
sum = 0
p60 = 0
p80 = 0
for i,j in ls:
    if i < 60 : p60 += j
    if i < 80 : p80 += j
    sum += j
print(p60/sum*100," ",p80/sum*100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-b7fa4102ca72> in <module>
#       1 path = "./data/github/github.txt"
#       2 mp_node,mp_edge = load_data(path)
# ----> 3 ls = degree_distribute(mp_node)
#       4 sum = 0
#       5 p60 = 0
#
# <ipython-input-1-d2f5478ae0e5> in degree_distribute(mp_node, show, logx, logy, coeff, cumulation)
#     216
#     217     if cumulation == True :
# --> 218         cnt = sum(y)
#     219         for i in range(len(x)):
#     220             cnt -= y[i]
#
# TypeError: 'int' object is not callable

# %%
for i in range(len(x)):
    print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-4513b4a6322f> in <module>
# ----> 1 for i in range(len(x)):
#       2     print(x)
#
# NameError: name 'x' is not defined

# %%
tmp_node = [set() for i in range(p)]

for par in range(len(part_edge)):
    for i in part_node[par]: tmp_node[par].add(i.id)
    cnt = 0
    print("edges:"+str(len(part_edge[par])))
    print("nodes:"+str(len(part_node[par])))
    for edge in part_edge[par]:
        for node in mp_edge[edge].nodes:
#             print(node)
#             print(mp_node[node])
            if node in tmp_node[par]:
                cnt += 1
    cur_p += 1
    print(cnt)
# Out:
# edges:56433
# nodes:5653
# 277912
# edges:25730
# nodes:5653
# 59056
# edges:15618
# nodes:5653
# 28610
# edges:7641
# nodes:5653
# 14208
# edges:7349
# nodes:5653
# 12455
# edges:7531
# nodes:5653
# 11444
# edges:7756
# nodes:5653
# 10089
# edges:8023
# nodes:5653
# 9310
# edges:7767
# nodes:5653
# 8748
# edges:7984
# nodes:5642
# 8405

# %%
k_1 = sum([len(i) for i in part_edge]) - edge_number
print(k_1)
# Out:
# 30965
