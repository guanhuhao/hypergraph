# %%
import matplotlib.pyplot as plt 
# path = "./github.txt.log"
# path = "./out.actor-movie.log"
# path = "./out.dblp-author.log"
path = "./out.dbpedia-location.log"
# path = "./out.dbpedia-team.log"
# path = "./wiki.txt.log"

with open(path,"r") as file:
    data_p = {}
    for line in file:
        if line[0] == "#" : continue
        p,sheild,per,k_1,runtime = line[0:-1].split(" ")
        p = int(p)
        sheild = int(sheild)
        per = float(per)
        k_1 = int(k_1)
        runtime = int(runtime)
        
        if data_p.get(p) == None : data_p[p] = []
        
        data_p[p].append((sheild,per,k_1,runtime))
        
def draw_per_k(p):
    x = [item[1] for item in data_p[p]]
    y = [item[2] for item in data_p[p]]
    print(x)
    print(y)
#     plt.yscale('log')
    plt.xscale('logit')
    plt.plot(x,y)
    plt.show()
    
    rec_pos = 0  
    for i in range(len(y)): 
        if y[i] < y[rec_pos]: 
            rec_pos = i
    print("sheild per:",x[i],"mini k-1:",y[i])
    
def draw_per_time(p):
    x = [item[1] for item in data_p[p]]
    y = [item[3] for item in data_p[p]]
    print(x)
    print(y)
#     plt.yscale('log')
    plt.xscale('logit')
    plt.plot(x,y)
    plt.show()
    
    rec_pos = 0  
    for i in range(len(y)): 
        if y[i] < y[rec_pos]: 
            rec_pos = i
    print("sheild per:",x[i],"mini k-1:",y[i])
    
draw_per_k(8)
draw_per_time(8)
# Out:
# [0.0, 1.77802e-07, 0.472529, 0.672378, 0.831958, 0.922484, 0.964238, 0.982593, 0.990461, 0.994359, 0.996419, 0.997613, 0.998302, 0.998754, 0.999262, 0.999534, 0.999675, 0.99977, 0.999852, 0.999902, 0.999937, 0.999958, 0.999973, 0.999982, 0.999988, 0.999992, 0.999995, 0.999996, 0.999998, 0.999998, 0.999999, 0.999999, 0.999999, 1.0]
# [2991957, 2991957, 2295162, 1725063, 1498242, 1406011, 1360213, 1339542, 1335392, 1331796, 1329827, 1329277, 1329501, 1327917, 1328966, 1329899, 1329278, 1329506, 1330328, 1328799, 1329348, 1329546, 1328940, 1330761, 1329835, 1330062, 1330251, 1330417, 1330612, 1330436, 1330308, 1329870, 1329508, 1330570]
# sheild per: 1.0 mini k-1: 1330570
# [0.0, 1.77802e-07, 0.472529, 0.672378, 0.831958, 0.922484, 0.964238, 0.982593, 0.990461, 0.994359, 0.996419, 0.997613, 0.998302, 0.998754, 0.999262, 0.999534, 0.999675, 0.99977, 0.999852, 0.999902, 0.999937, 0.999958, 0.999973, 0.999982, 0.999988, 0.999992, 0.999995, 0.999996, 0.999998, 0.999998, 0.999999, 0.999999, 0.999999, 1.0]
# [13122, 13680, 16293, 19161, 21989, 23719, 24600, 25183, 25526, 25750, 25887, 26443, 28215, 29075, 28023, 29319, 28190, 26473, 27640, 27076, 27793, 27894, 27957, 28162, 28270, 28594, 28418, 27867, 28311, 29623, 29246, 28364, 28581, 28210]
# sheild per: 1.0 mini k-1: 28210

# %%
# Out:
# {2: [(0, 0.0, 27351, 266), (1, 3.30934e-05, 27351, 303), (2, 0.686978, 16085, 309), (3, 0.820237, 11122, 343), (5, 0.902714, 6974, 377), (7, 0.932986, 5195, 388), (11, 0.959039, 3510, 416), (17, 0.973757, 2460, 438), (26, 0.982643, 1980, 457), (38, 0.988285, 2535, 494), (58, 0.992223, 3124, 506), (83, 0.994837, 3406, 532), (114, 0.996567, 3616, 555), (155, 0.997675, 3785, 607), (203, 0.998469, 3827, 589), (268, 0.998974, 3888, 620), (353, 0.999322, 3947, 650), (470, 0.999545, 3924, 639), (549, 0.999694, 3856, 688), (673, 0.999793, 3873, 663), (781, 0.999859, 3905, 699), (990, 0.999909, 3972, 687), (1136, 0.999934, 4016, 716), (1438, 0.999959, 4024, 725), (1565, 0.999967, 4055, 680), (1611, 0.999975, 4061, 715), (1