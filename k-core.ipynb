# %%
from src.Data import load_data
path = "./data/github/github.txt"
class Node:
    def __init__(self,id,degree,edge_list):
        self.id = id
        self.degree = degree 
        self.edge_list = edge_list

mp = {}
bia = 1000000000

with open(path,'r') as f:
    for line in f:
        if(line[0]=='#' or line=='\n') : continue
        data = [int(i) for i in line[0:-1].split(" ")]
        n_id = data[0]
        n_degree = data[1]
        n_edges = set(data[2:])
        if mp.get(n_id) == None : mp[n_id] = Node(n_id,0,[])
        for edge in n_edges:
            e_id = edge + bia;
            if mp.get(e_id) == None : mp[e_id] = Node(e_id,0,[])
            mp[n_id].degree += 1
            mp[n_id].edge_list.append(e_id)
            
            mp[e_id].degree += 1
            mp[e_id].edge_list.append(n_id)
op = {key:value for key,value in mp.items()}



k = 0

while len(op) > 10:
    degree = {}
    for node in op.values():
        if degree.get(node.degree) == None : degree[node.degree] = []
        degree[node.degree].append(node)
    degree = [(key,value) for key,value in degree.items()]
    degree.sort(key = lambda x:x[0])
    
#     print([(i,len(j)) for i,j in degree])
    for key,value in degree:
        if key > k : break
        for node in value:
            for edge in node.edge_list:
                if op.get(edge) != None:
                    op[edge].degree -= 1
            del op[node.id]
    k += 1
    print("k:"+str(k) +"   ret:"+str(len(op)))
# Out:
# k:1   ret:177386
# k:2   ret:70956
# k:3   ret:38512
# k:4   ret:27045
# k:5   ret:21084
# k:6   ret:17277
# k:7   ret:14607
# k:8   ret:12596
# k:9   ret:11045
# k:10   ret:9780
# k:11   ret:8716
# k:12   ret:7855
# k:13   ret:7095
# k:14   ret:6468
# k:15   ret:5915
# k:16   ret:5435
# k:17   ret:5005
# k:18   ret:4600
# k:19   ret:4256
# k:20   ret:3908
# k:21   ret:3603
# k:22   ret:3316
# k:23   ret:3064
# k:24   ret:2855
# k:25   ret:2683
# k:26   ret:2486
# k:27   ret:2311
# k:28   ret:2170
# k:29   ret:2002
# k:30   ret:1856
# k:31   ret:1722
# k:32   ret:1598
# k:33   ret:1480
# k:34   ret:1383
# k:35   ret:1284
# k:36   ret:1180
# k:37   ret:1087
# k:38   ret:995
# k:39   ret:888
# k:40   ret:801
# k:41   ret:707
# k:42   ret:609
# k:43   ret:509
# k:44   ret:396
# k:45   ret:274
# k:46   ret:139
# k:47   ret:18
# k:48   ret:0

# %%
from src.Data import load_data
class K_core:
    def __init__(self,path):
        self.path = path
        self.node,self.edge = load_data(path)
#         print(self.node)
    def get_kcore(self,mini_size):
        mp_node = {key:value.degree for key,value in self.node.items()}
        mp_edge = {key:value.degree for key,value in self.edge.items()}
        k = 0;
        while len(mp_node) > 0:
            del_node = []
            del_edge = []
            for node_id,degree in mp_node.items():
                if degree <= k : del_node.append(node_id)
            for edge_id,degree in mp_edge.items():
                if degree <= k : del_edge.append(edge_id)
            if len(mp_node) - len(del_node) < mini_size : 
                print("k:",k," node number:",len(mp_node)," edge number:",len(mp_edge))
                return [self.node[node_id] for node_id in mp_node.keys()]
            for node_id in del_node:
                for edge_id in self.node[node_id].edges:
                    if edge_id not in mp_edge.keys() : continue
                    mp_edge[edge_id] -= 1
                del mp_node[node_id]
            for edge_id in del_edge:
                for node_id in self.edge[edge_id].nodes:
                    if node_id not in mp_node.keys() : continue
                    mp_node[node_id] -= 1
                del mp_edge[edge_id]
#             print("k:",k," ",len(mp_node)," ",len(mp_edge))
            k += 1
        
            
    def del_node(self,nodes):
        for node in nodes:
#             print(self.node[node.id].degree)
            if node.id not in self.node.keys() : continue
            for edge_id in node.edges:
                if edge_id not in self.edge.keys() : continue
                self.edge[edge_id].degree -= 1
                if self.edge[edge_id].degree == 0 :
                    del self.edge[edge_id]
            del self.node[node.id]
    def find_connection(self,nodes):
        ret  = set()
        ret.add(nodes[0])
        for edge_id in nodes[0].edges:
            for node in nodes[1:-1]:
                if node.id in self.edge[edge_id].nodes: 
                    ret.add(node)
        return ret

# %%
kcore = K_core(path = "./data/github/github.txt")
for i in range(10):
    
    result = kcore.get_kcore(10)
    a = kcore.find_connection(result)
    print("len result:",len(result))
    print("len a:",len(a))
# for node in result:
#     print(node.id)
# print("node number:",len(kcore.node)," edge number:",len(kcore.edge))
    print("---")
    kcore.del_node(a)
# print("node number:",len(kcore.node)," edge number:",len(kcore.edge))
# result = kcore.get_kcore(10)
# a = kcore.find_connection(result)
# print("len result:",len(result))
# print("len a:",len(a))
# for node in result:
#     print(node.id)
# Out:
# k: 47  node number: 15  edge number: 3
# len result: 15
# len a: 14
# ---
# k: 44  node number: 70  edge number: 64
# len result: 70
# len a: 69
# ---
# k: 38  node number: 112  edge number: 102
# len result: 112
# len a: 111
# ---
# k: 34  node number: 17  edge number: 51
# len result: 17
# len a: 16
# ---
# k: 33  node number: 88  edge number: 95
# len result: 88
# len a: 87
# ---
# k: 30  node number: 185  edge number: 138
# len result: 185
# len a: 184
# ---
# k: 27  node number: 47  edge number: 89
# len result: 47
# len a: 46
# ---
# k: 26  node number: 113  edge number: 125
# len result: 113
# len a: 111
# ---
# k: 24  node number: 255  edge number: 190
# len result: 255
# len a: 226
# ---
# k: 22  node number: 107  edge number: 129
# len result: 107
# len a: 100
# ---
